# %% [markdown]
# #### Project structure:
#                         app.py----app logic
#                         requirment.txt----required modules
#                         .gitignore---->git ignore file name
#                         readme.md--->read me file
#
#     python current version---3.14.6
#
#     Creating new vertical environments
#             - Python -m ven env_name
#
#     Activate vartiual environment
#             --- env_name\Scripts\activate -- windows
#             --- source env_name\bin\activate----mac
#
#
#     To create empty directory
#         - mkdir directory_name-----empty directory
#     To change directory path
#         - cd directory_path
#     To create empty file
#         - touch filename
#     To install requirements
#         - pip install -r requirements.txt
