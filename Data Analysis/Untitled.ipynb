# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Reading the dataset
import pandas as pd
df = pd.read_csv("Sales.csv")
print(df)
# Out:
#      order_id        date        item_name  item_type  item_price  quantity  \
# 0           1  07-03-2022         Aalopuri   Fastfood          20        13
# 1           2   8/23/2022          Vadapav   Fastfood          20        15
# 2           3  11/20/2022          Vadapav   Fastfood          20         1
# 3           4  02-03-2023  Sugarcane juice  Beverages          25         6
# 4           5  10-02-2022  Sugarcane juice  Beverages          25         8
# ..        ...         ...              ...        ...         ...       ...
# 995       996   3/19/2023          Frankie   Fastfood          50        10
# 996       997   9/20/2022         Sandwich   Fastfood          60         7
# 997       998   1/26/2023         Sandwich   Fastfood          60        13
# 998       999   8/27/2022         Panipuri   Fastfood          20         5
# 999      1000   5/29/2022         Aalopuri   Fastfood          20         3
#
# ...

# %%
# Find info of data set

import pandas as pd
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   order_id            1000 non-null   int64
#  1   date                1000 non-null   object
#  2   item_name           1000 non-null   object
#  3   item_type           1000 non-null   object
#  4   item_price          1000 non-null   int64
#  5   quantity            1000 non-null   int64
#  6   transaction_amount  1000 non-null   int64
#  7   transaction_type    893 non-null    object
#  8   received_by         1000 non-null   object
#  9   time_of_sale        1000 non-null   object
# dtypes: int64(4), object(6)
# memory usage: 78.3+ KB

# %%
# Find the statistical information for integer columns

df.describe()
# Out:
#           order_id   item_price     quantity  transaction_amount
# count  1000.000000  1000.000000  1000.000000         1000.000000
# mean    500.500000    33.315000     8.162000          275.230000
# std     288.819436    14.921744     4.413075          204.402979
# min       1.000000    20.000000     1.000000           20.000000
# 25%     250.750000    20.000000     4.000000          120.000000
# 50%     500.500000    25.000000     8.000000          240.000000
# 75%     750.250000    50.000000    12.000000          360.000000
# max    1000.000000    60.000000    15.000000          900.000000

# %%
# Find the statistical information for string  columns 

df.describe(include = "object")
# Out:
#              date    item_name item_type transaction_type received_by  \
# count        1000         1000      1000              893        1000
# unique        348            7         2                2           2
# top     8/31/2022  Cold coffee  Fastfood             Cash         Mr.
# freq            8          161       686              476         512
#
#        time_of_sale
# count          1000
# unique            5
# top           Night
# freq            205

# %%
# Access column data - for single cloumn
df["item_name"]
# Out:
# 0             Aalopuri
# 1              Vadapav
# 2              Vadapav
# 3      Sugarcane juice
# 4      Sugarcane juice
#             ...
# 995            Frankie
# 996           Sandwich
# 997           Sandwich
# 998           Panipuri
# 999           Aalopuri
# Name: item_name, Length: 1000, dtype: object

# %%
# Access column data - for multiple cloumn

df[["item_name","item_type","time_of_sale"]]
# Out:
#            item_name  item_type time_of_sale
# 0           Aalopuri   Fastfood        Night
# 1            Vadapav   Fastfood    Afternoon
# 2            Vadapav   Fastfood    Afternoon
# 3    Sugarcane juice  Beverages        Night
# 4    Sugarcane juice  Beverages      Evening
# ..               ...        ...          ...
# 995          Frankie   Fastfood      Evening
# 996         Sandwich   Fastfood      Evening
# 997         Sandwich   Fastfood      Evening
# 998         Panipuri   Fastfood    Afternoon
# 999         Aalopuri   Fastfood     Midnight
#
# [1000 rows x 3 columns]

# %%
# Find the unique value in column

df["item_name"].unique()
# Out:
# array(['Aalopuri', 'Vadapav', 'Sugarcane juice', 'Panipuri', 'Frankie',
#        'Sandwich', 'Cold coffee'], dtype=object)

# %%
# Find the unique value in count

df["item_name"].value_counts()
# Out:
# item_name
# Cold coffee        161
# Sugarcane juice    153
# Panipuri           150
# Frankie            139
# Aalopuri           134
# Vadapav            134
# Sandwich           129
# Name: count, dtype: int64

# %%
# Find the unique value in transaction_type

df["transaction_type"].value_counts()
# Out:
# transaction_type
# Cash      476
# Online    417
# Name: count, dtype: int64

# %%
# Find the unique value in transaction_type

df["item_type"].value_counts()
# Out:
# item_type
# Fastfood     686
# Beverages    314
# Name: count, dtype: int64

# %%
# Handling the missing values
df.isnull()
# Out:
#      order_id   date  item_name  item_type  item_price  quantity  \
# 0       False  False      False      False       False     False
# 1       False  False      False      False       False     False
# 2       False  False      False      False       False     False
# 3       False  False      False      False       False     False
# 4       False  False      False      False       False     False
# ..        ...    ...        ...        ...         ...       ...
# 995     False  False      False      False       False     False
# 996     False  False      False      False       False     False
# 997     False  False      False      False       False     False
# 998     False  False      False      False       False     False
# 999     False  False      False      False       False     False
#
#      transaction_amount  transaction_type  received_by  time_of_sale
# 0                 False              True        False         False
# ...

# %%
# Handling the missing values
# Count the null values in each columns

df.isnull().sum()
# Out:
# order_id                0
# date                    0
# item_name               0
# item_type               0
# item_price              0
# quantity                0
# transaction_amount      0
# transaction_type      107
# received_by             0
# time_of_sale            0
# dtype: int64

# %%
# handling transaction_type column missing value

df["transaction_type"].mode()
# Out:
# 0    Cash
# Name: transaction_type, dtype: object

# %%
# handling transaction_type column missing value    

df["transaction_type"] = df["transaction_type"].fillna("Cash")
df.head()
# Out:
#    order_id        date        item_name  item_type  item_price  quantity  \
# 0         1  07-03-2022         Aalopuri   Fastfood          20        13
# 1         2   8/23/2022          Vadapav   Fastfood          20        15
# 2         3  11/20/2022          Vadapav   Fastfood          20         1
# 3         4  02-03-2023  Sugarcane juice  Beverages          25         6
# 4         5  10-02-2022  Sugarcane juice  Beverages          25         8
#
#    transaction_amount transaction_type received_by time_of_sale
# 0                 260             Cash         Mr.        Night
# 1                 300             Cash         Mr.    Afternoon
# 2                  20             Cash         Mr.    Afternoon
# 3                 150           Online         Mr.        Night
# 4                 200           Online         Mr.      Evening

# %%
df["transaction_type"].isnull().sum()
# Out:
# np.int64(0)

# %%
# Device co;umn into categorical and numberical

categorical_columns =[ "data","item_name","item_type","transaction_type","received_amount","transaction_type","received_by"]
numrecal_columns =["order_id","item_price","quantity","transaction_amount"]
df.columns
# Out:
# Index(['order_id', 'date', 'item_name', 'item_type', 'item_price', 'quantity',
#        'transaction_amount', 'transaction_type', 'received_by',
#        'time_of_sale'],
#       dtype='object')

# %%
df.drop(["Order_id","Data"], axis = 1,inplace=True)
df.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 df.drop(["Order_id","Data"], axis = 1,inplace=True)
#       2 df.head()
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\frame.py:5603, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5599                 weight  250.0   150.0
#    5600         falcon  speed   320.0   250.0
#    5601                 weight  1.0     0.8
#    5602         """
# -> 5603         return super().drop(
#    5604             labels=labels,
#    5605             axis=axis,
#    5606             index=index,
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\generic.py:4810, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4806         obj = self
#    4807
#    4808         for axis, labels in axes.items():
# ...

# %%
# Data transformation
categorical_columns =[ "data","item_name","item_type","transaction_type","received_amount","transaction_type","received_by"]

# %%
df["item_name"].unique()
item_name_map={'Aalopuri':1,'Vadapav':2,'Sugarcane juice':3, 'Panipuri':4, 'Frankie':5,
       'Sandwich':6, 'Cold coffee':7}
df["item_name"]=df["item_name"].replace(item_name_map)
df.head()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_15560\2057347842.py:4: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df["item_name"]=df["item_name"].replace(item_name_map)
#    order_id        date  item_name  item_type  item_price  quantity  \
# 0         1  07-03-2022          1   Fastfood          20        13
# 1         2   8/23/2022          2   Fastfood          20        15
# 2         3  11/20/2022          2   Fastfood          20         1
# 3         4  02-03-2023          3  Beverages          25         6
# 4         5  10-02-2022          3  Beverages          25         8
#
#    transaction_amount transaction_type received_by time_of_sale
# 0                 260              NaN         Mr.        Night
# ...

# %%
df["item_name"].unique()
item_type_map={"Fastfood":0,"Behverages":1}
df["item_type"]=df["item_type"].replace(item_type_map)
df.head()
# Out:
#    order_id        date        item_name  item_type  item_price  quantity  \
# 0         1  07-03-2022         Aalopuri          0          20        13
# 1         2   8/23/2022          Vadapav          0          20        15
# 2         3  11/20/2022          Vadapav          0          20         1
# 3         4  02-03-2023  Sugarcane juice  Beverages          25         6
# 4         5  10-02-2022  Sugarcane juice  Beverages          25         8
#
#    transaction_amount  transaction_type  received_by time_of_sale
# 0                 260                 1            1        Night
# 1                 300                 1            1    Afternoon
# 2                  20                 1            1    Afternoon
# 3                 150                 0            1        Night
# 4                 200                 0            1      Evening

# %%
df["transaction_type"].unique()
received_by_map={"Mrs.":0,"Mr.":1}
transaction_type_map={"Online":0,"Cash":1}
df["transaction_type"]=df["transaction_type"].replace(transaction_type_map)
df["received_by"]=df["received_by"].replace(received_by_map)
df.head()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_3400\1470844765.py:4: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df["transaction_type"]=df["transaction_type"].replace(transaction_type_map)
# C:\Users\HP\AppData\Local\Temp\ipykernel_3400\1470844765.py:5: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df["received_by"]=df["received_by"].replace(received_by_map)
#    order_id        date        item_name  item_type  item_price  quantity  \
# 0         1  07-03-2022         Aalopuri   Fastfood          20        13
# ...

# %%
df["transaction_type"] = df["transaction_type"].fillna("Cash")
df.head()
# Out:
#    order_id        date        item_name  item_type  item_price  quantity  \
# 0         1  07-03-2022         Aalopuri          0          20        13
# 1         2   8/23/2022          Vadapav          0          20        15
# 2         3  11/20/2022          Vadapav          0          20         1
# 3         4  02-03-2023  Sugarcane juice  Beverages          25         6
# 4         5  10-02-2022  Sugarcane juice  Beverages          25         8
#
#    transaction_amount  transaction_type  received_by time_of_sale
# 0                 260                 1            1        Night
# 1                 300                 1            1    Afternoon
# 2                  20                 1            1    Afternoon
# 3                 150                 0            1        Night
# 4                 200                 0            1      Evening

# %%
# Data Visualization

# count plot
plt.figure(figsize=(8,5))
sns.countplot(data=df,x="item_name")
plt.show()

# %%
# Data Visualization
# count plot

plt.figure(figsize=(8,5))
sns.countplot(data=df,x="item_name",hue="transaction_type")
plt.show()

# %%
# Data Visualization
# count plot

plt.figure(figsize=(8,5))
sns.countplot(data=df,x="time_of_sales",hue="transaction_type")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[21], line 5
#       1 # Data Visualization
#       2 # count plot
#       3
#       4 plt.figure(figsize=(8,5))
# ----> 5 sns.countplot(data=df,x="time_of_sales",hue="transaction_type")
#       6 plt.show()
#
# File ~\AppData\Roaming\Python\Python313\site-packages\seaborn\categorical.py:2631, in countplot(data, x, y, hue, order, hue_order, orient, color, palette, saturation, fill, hue_norm, stat, width, dodge, gap, log_scale, native_scale, formatter, legend, ax, **kwargs)
#    2628 elif x is not None and y is not None:
#    2629     raise TypeError("Cannot pass values for both `x` and `y`.")
# -> 2631 p = _CategoricalAggPlotter(
#    2632     data=data,
#    2633     variables=dict(x=x, y=y, hue=hue),
#    2634     order=order,
#    2635     orient=orient,
#    2636     color=color,
#    2637     legend=legend,
# ...

# %%
sns.scatterplot
sns.kdeplot
sns,barplot
sns,boxplot
sns.lineplot
sns.pairplot
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 3
#       1 sns.scatterplot
#       2 sns.kdeplot
# ----> 3 sns,barplot
#       4 sns,boxplot
#       5 sns.lineplot
#       6 sns.pairplot
#
# NameError: name 'barplot' is not defined
